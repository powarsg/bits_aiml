# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
import time

from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import f1_score

# %%
print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.19.0

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import tensorflow_datasets as tfds
from tensorflow_datasets.core.download import DownloadConfig

download_config = DownloadConfig(verify_ssl=False)

builder = tfds.builder("")

builder.download_and_prepare(download_config=download_config)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
dataset_train = builder.as_dataset(split="train[:90%]", as_supervised=True)
dataset_test  = builder.as_dataset(split="train[90%:]", as_supervised=True)

dataset_info = builder.info

# %%
for img, label in dataset_train.take(1):
    print(img.shape, label)

# %%
(dataset_train, dataset_test), dataset_info = tfds.load(
    "jena_climate",
    split=["train[:90%]", "train[90%:]"],   # 90/10 split
    as_supervised=True,
    with_info=True
)

# %%
print(dataset_info)
